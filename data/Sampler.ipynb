# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_json("./data/Original/Patio_Lawn_and_Garden_5.json", lines=True, encoding='latin-1')

# %%
sampled_df = df.sample(frac=0.1, random_state=42)

# %%
sampled_df.to_json("Patio_Lawn_and_Garden_5.json", orient='records', lines=True)

# %%
df2 = pd.read_json("Patio_Lawn_and_Garden_5.json", lines=True, encoding='latin-1')

# %%
df2
# Out:
#        overall  vote  verified   reviewTime      reviewerID        asin  \
# 0            2  None      True   07 8, 2014  A103Z7LBCXKHF3  B00004R9WN
# 1            5  None      True   01 9, 2014   AZNUNL2GIX0AP  B000WQIZJ0
# 2            5  None      True   01 6, 2017  A1SA7STKTN80ZX  B0014E3MT2
# 3            1  None      True   06 6, 2017  A1A9PO9LWLEH3R  B00A9Y4490
# 4            1  None      True  05 15, 2018   A2NG7M7U2EOTM  B002FGU2NM
# ...        ...   ...       ...          ...             ...         ...
# 79837        5  None      True   06 6, 2016  A2V3ZG7FOA5B40  B01BAAM9ZC
# 79838        5  None      True  05 29, 2018   AGTKW4F49ZR48  B00HH5NILY
# 79839        4  None      True  09 10, 2017  A3HAHFKP822JBE  B000E17BIO
# 79840        5  None      True   10 5, 2015  A1XL4YLORJ5IBS  B008UC9GA0
# 79841        4  None      True  12 10, 2015  A33W5XU72IHJHM  B0001PG2RO
#
#                 reviewerName  \
# 0                K. Calderon
# 1                       Kota
# ...

# %%
df = pd.read_json("./data/Original/Sports_and_Outdoors_5.json", lines=True, encoding='latin-1')
sampled_df = df.sample(frac=0.1, random_state=42)
sampled_df.to_json("Sports_and_Outdoors_5.json", orient='records', lines=True)

# %%
df = pd.read_json("./data/Original/Tools_and_Home_Improvement_5.json", lines=True, encoding='latin-1')
sampled_df = df.sample(frac=0.1, random_state=42)
sampled_df.to_json("Tools_and_Home_Improvement_5.json", orient='records', lines=True)

# %%
df = pd.read_json("./data/Original/Toys_and_Games_5.json", lines=True, encoding='latin-1')
sampled_df = df.sample(frac=0.1, random_state=42)
sampled_df.to_json("Toys_and_Games_5.json", orient='records', lines=True)

# %%
df = pd.read_json("./data/Original/Video_Games_5.json", lines=True, encoding='latin-1')
sampled_df = df.sample(frac=0.1, random_state=42)
sampled_df.to_json("Video_Games_5.json", orient='records', lines=True)

# %%
df = pd.read_json("./data/Original/Movies_and_TV_5.json", lines=True, encoding='latin-1')
sampled_df = df.sample(frac=0.1, random_state=42)
sampled_df.to_json("Movies_and_TV_5.json", orient='records', lines=True)

# %%
df = pd.read_json("./data/Original/Kindle_Store_5.json", lines=True, encoding='latin-1')
sampled_df = df.sample(frac=0.1, random_state=42)
sampled_df.to_json("Kindle_Store_5.json", orient='records', lines=True)

# %%
pd.read_json("Movies_and_TV_5.json", lines=True, encoding='latin-1')
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0             1     False   10 9, 2012  A3IBNV44XC648X  B004RD37JW
# 1             5      True  11 28, 2015   ABITPLKOSQOMO  B00LT1JHLW
# 2             3      True  05 30, 2016   AA6UPTZJ1GXK2  B000TJ6PBU
# 3             3      True   01 4, 2017  A1W5RUAJRI8ZD3  B0013J55B6
# 4             5      True  04 12, 2015  A2FT7XIQYANN87  6302718872
# ...         ...       ...          ...             ...         ...
# 340997        2     False  06 20, 2010  A19ZXK9HHVRV1X  B001TRDQIQ
# 340998        5      True   07 7, 2014  A25LKR3TYYYNFN  B00IKM5LXG
# 340999        5      True   11 9, 2015  A3F72UADTVGB27  B004ZKKL5A
# 341000        5      True   08 2, 2017   AZ5O5JAF3CF8F  6303027016
# 341001        1     False  01 11, 2010  A3SP9SP9QBE5W2  6303094902
#
#                                style      reviewerName  \
# 0       {'Format:': ' Amazon Video'}       texadelphia
# ...
